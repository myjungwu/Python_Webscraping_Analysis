# %%
import warnings

warnings.filterwarnings(action='ignore')

# %%
#문자열에 있는 특수문자를 제거하는 함수
def clean_text(text):
    import re
    text = text.replace("\n", "")
    cleaned_text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]','', text)
    cleaned_text = cleaned_text.replace(' ','')
    return cleaned_text

# %%
clean_text("김영철의 파워FM - 진짜 미국식 영어 810회 - 타일러의 진짜 미국식 영어 = Don't be so stubborn. = 억지 좀 부리지 마세요!!")
# Out:
# '김영철의파워FM진짜미국식영어810회타일러의진짜미국식영어Dontbesostubborn억지좀부리지마세요'

# %% [markdown]
# ### 팟빵 다운로드 1단계
# * 팟빵 id 와 제목을 함수의 인자로 받는다.
# *
# 첫번의 208개의 에피소만 다운로드 받고 있다
# *
# 저장되는 mp3 파일명을 에피소드의 타이틀로 설정함

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json
import os

#https://www.podbbang.com/channels/16524
#url = 'http://www.podbbang.com/_m_api/podcasts/16524/episodes?offset=0&sort=pubdate:desc&episode_id=0&limit=8&with=summary&cache=0'
url = 'https://app-api6.podbbang.com/channels/16524/episodes?offset=0&limit=20&sort=desc&episode_id=0&focus_center=0&with=image'
res = requests.get(url)
print(res.status_code)
if res.ok:
    json_data = res.json()    
#     #{data:[{},{},{}]}
    episode_list = json_data['data']
    print(len(episode_list))

    for episode in episode_list:
        print('------')
        #에피소드의 제목
        title = episode['title']
        #에피소드 다운로드 url
        mp3_url = episode['media']['url']
        print(title, mp3_url)
        
        #url 값이 있으면 다운로드 받아야 함
        if mp3_url:            
            req_header = {
                'referer':'https://www.podbbang.com/channels/16524',
                'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36'
            }
                        
            if not os.path.isdir('mp3'):
                os.mkdir('mp3')
            
            dir_name = os.path.join('mp3','미드처방전')
            #print(dir_name) #mp3\미드처방전

            #해당 디렉토리가 없으면
            if not os.path.isdir(dir_name):
                #디렉토리를 생성
                os.makedirs(dir_name)
            
            #해당 url에서 파일명만 추출
            #file_name = os.path.basename(mp3_url)
            file_name = f'{clean_text(title)}.mp3'
            #생성된 디렉토리명과 파일명을 합쳐주기
            file_name = os.path.join(dir_name,file_name)#dir_name+'/'+file_name            
            print(file_name)

            res = requests.get(mp3_url, headers=req_header)
            print(res.status_code)
            if res.ok:
                #response 객체에서 binary 데이터 추출
                mp3_bin = res.content                
                #binary 데이터를 local 파일로 저장
                with open(file_name, 'wb') as file:
                    file.write(mp3_bin)
# Out:
# 200
# 20
# ------
# 120회 억지로 기분 나아지게 하지 맙시다 https://file.ssenhosting.com/data1/pb_22419/watchthegrass.mp3?cmad=2f64617461312f70625f32323431392f776174636874686567726173735f6133312e6d7033
# mp3\미드처방전\120회억지로기분나아지게하지맙시다.mp3
# 200
# ------
# 119회 한국 코로나 대응에 대한 외신 뉴스와 반응 https://file.ssenhosting.com/data1/pb_22419/74overseasnews.mp3?cmad=2f64617461312f70625f32323431392f37346f766572736561736e6577735f6133312e6d7033
# mp3\미드처방전\119회한국코로나대응에대한외신뉴스와반응.mp3
# 200
# ------
# 118회 이런 콜라보 웃음 폭탄, 영어 아웃 오브 안중 주의 https://file.ssenhosting.com/data1/pb_22419/hand2020226.mp3?cmad=2f64617461312f70625f32323431392f68616e64323032303232365f6133312e6d7033
# mp3\미드처방전\118회이런콜라보웃음폭탄영어아웃오브안중주의.mp3
# 200
# ------
# 117회 넷플릭스 본다면 이거슨 꿀팁 '나 홀로 그대' 공동구매각 https://file.ssenhosting.com/data1/pb_22419/handholo1.mp3?cmad=2f64617461312f70625f32323431392f68616e64686f6c6f315f6133312e6d7033
# mp3\미드처방전\117회넷플릭스본다면이거슨꿀팁나홀로그대공동구매각.mp3
# 200
# ------
# 116회 넌 라면먹을 계획이 다 있구나, 라끼남 맛 감탄을 영어로 https://file.ssenhosting.com/data1/pb_22419/hand2012.mp3?cmad=2f64617461312f70625f32323431392f68616e64323031325f6133312e6d7033
# mp3\미드처방전\116회넌라면먹을계획이다있구나라끼남맛감탄을영어로.mp3
# 200
# ------
# 115회 일간 <소울 영어> 삶이 전쟁터 같을 때 https://file.ssenhosting.com/data1/pb_22419/souleng7.mp3?cmad=2f64617461312f70625f32323431392f736f756c656e67375f6133312e6d7033
# mp3\미드처방전\115회일간소울영어삶이전쟁터같을때.mp3
# 200
# ------
# 114회 라떼 이즈 홀스, 꼰대 선배를 대하는 임진주 작가, 멜로가 체질 2탄 https://file.ssenhosting.com/data1/pb_22419/handmelo2.mp3?cmad=2f64617461312f70625f32323431392f68616e646d656c6f325f6133312e6d7033
# mp3\미드처방전\114회라떼이즈홀스꼰대선배를대하는임진주작가멜로가체질2탄.mp3
# 200
# ------
# 113회 [고민사연] 어른이 되었지만 여전히 어설픈 나를 만날 때 https://file.ssenhosting.com/data1/pb_22419/mid7.mp3?cmad=2f64617461312f70625f32323431392f6d6964375f6133312e6d7033
# mp3\미드처방전\113회고민사연어른이되었지만여전히어설픈나를만날때.mp3
# 200
# ------
# 112회 북한 사투리 억양으로 영어 연기! 가능한기가 이그이? <사랑의 불시착> https://file.ssenhosting.com/data1/pb_22419/65hand5.mp3?cmad=2f64617461312f70625f32323431392f363568616e64355f6133312e6d7033
# mp3\미드처방전\112회북한사투리억양으로영어연기가능한기가이그이사랑의불시착.mp3
# 200
# ------
# 111회 리정혁 동무, 기카자요! 드라마 '사랑의 불시착' https://file.ssenhosting.com/data1/pb_22419/64hand5.mp3?cmad=2f64617461312f70625f32323431392f363468616e64355f6133312e6d7033
# mp3\미드처방전\111회리정혁동무기카자요드라마사랑의불시착.mp3
# 200
# ------
# 110회 [고민사연] 자꾸 미루는 나, 게으른건가요? https://file.ssenhosting.com/data1/pb_22419/midwalter1.mp3?cmad=2f64617461312f70625f32323431392f6d696477616c746572315f6133312e6d7033
# mp3\미드처방전\110회고민사연자꾸미루는나게으른건가요.mp3
# 200
# ------
# 109회 오늘의 발연기는 '멜로가 체질' 짜증나게 이걸 왜 뽑았지? https://file.ssenhosting.com/data1/pb_22419/hand04.mp3?cmad=2f64617461312f70625f32323431392f68616e6430345f6133312e6d7033
# mp3\미드처방전\109회오늘의발연기는멜로가체질짜증나게이걸왜뽑았지.mp3
# 200
# ------
# 108회 [고민사연] 힘내라는 말은 화장실 갈때만 하는 걸로~! https://file.ssenhosting.com/data1/pb_22419/mid3dressmaker.mp3?cmad=2f64617461312f70625f32323431392f6d69643364726573736d616b65725f6133312e6d7033
# mp3\미드처방전\108회고민사연힘내라는말은화장실갈때만하는걸로.mp3
# 200
# ------
# 107회 동백꽃 필무렵, 자영이의 촌철대사 https://file.ssenhosting.com/data1/pb_22419/handprescription21.mp3?cmad=2f64617461312f70625f32323431392f68616e64707265736372697074696f6e32315f6133312e6d7033
# mp3\미드처방전\107회동백꽃필무렵자영이의촌철대사.mp3
# 200
# ------
# 106회 [고민사연] 쉴틈 없는 내 인생, 인도에 가야 쉬어지려나~ https://file.ssenhosting.com/data1/pb_22419/midprescription21.mp3?cmad=2f64617461312f70625f32323431392f6d6964707265736372697074696f6e32315f6133312e6d7033
# mp3\미드처방전\106회고민사연쉴틈없는내인생인도에가야쉬어지려나.mp3
# 200
# ------
# [동백꽃 필무렵] 임마님과 함께 하는 발연기 신코너, 한드처방전입니다. https://file.ssenhosting.com/data1/pb_22419/handprescription11.mp3?cmad=2f64617461312f70625f32323431392f68616e64707265736372697074696f6e31315f6133312e6d7033
# mp3\미드처방전\동백꽃필무렵임마님과함께하는발연기신코너한드처방전입니다.mp3
# 200
# ------
# 새로운 코너를 소개합니다. 심리상담사 마녀쌤과 함께 하는 '미드처방전' https://file.ssenhosting.com/data1/pb_22419/midprescription11.mp3?cmad=2f64617461312f70625f32323431392f6d6964707265736372697074696f6e31315f6133312e6d7033
# mp3\미드처방전\새로운코너를소개합니다심리상담사마녀쌤과함께하는미드처방전.mp3
# 200
# ------
# 103회 [미타임] 가을이 문제였다니! https://file.ssenhosting.com/data1/pb_22419/metime2222autumnisatfault.mp3?cmad=2f64617461312f70625f32323431392f6d6574696d6532323232617574756d6e697361746661756c745f6133312e6d7033
# mp3\미드처방전\103회미타임가을이문제였다니.mp3
# 200
# ------
# 102회 [미타임] 사람을 덜 만나라고? https://file.ssenhosting.com/data1/pb_22419/metime1004.mp3?cmad=2f64617461312f70625f32323431392f6d6574696d65313030345f6133312e6d7033
# mp3\미드처방전\102회미타임사람을덜만나라고.mp3
# 200
# ------
# 101회 [미타임] 모임에 나가면 벌어지는 일~! https://file.ssenhosting.com/data1/pb_22419/metime101.mp3?cmad=2f64617461312f70625f32323431392f6d6574696d653130315f6133312e6d7033
# mp3\미드처방전\101회미타임모임에나가면벌어지는일.mp3
# 200

# %% [markdown]
# ### 팟빵 다운로드 2단계
# * 20개의 에피소드를 다운로드 하는 함수로 선언
# * 채널 ID : channel_id
# * 채널 제목 : channel_title

# %%
def podbbang_download(channel_id, channel_title):
    import requests
    from bs4 import BeautifulSoup
    from urllib.parse import urljoin
    import json
    import os

    url = f'https://app-api6.podbbang.com/channels/{channel_id}/episodes'
    #?offset=0&limit=20&sort=desc&episode_id=0&focus_center=0&with=image'
    req_param = {
        "offset":0,
        "limit":20,
        "sort":"desc",
        "episode_id":0,
        "focus_center":0,
        "with":"image"        
    }

    res = requests.get(url, params=req_param)
    print(res.status_code)
    if res.ok:
        json_data = res.json()    
        #{data:[{},{},{}]}
        episode_list = json_data['data']
        print(len(episode_list))

        for episode in episode_list:
            print('------')
            #에피소드의 제목
            title = episode['title']
            #에피소드 다운로드 url
            mp3_url = episode['media']['url']
            print(title, mp3_url)

            #url 값이 있으면 다운로드 받아야 함
            if mp3_url:            
                req_header = {
                    'referer':f'https://www.podbbang.com/channels/{channel_id}',
                    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36'
                }

                if not os.path.isdir('mp3'):
                    os.mkdir('mp3')

                dir_name = os.path.join('mp3',channel_title)
                #print(dir_name) #mp3\미드처방전

                #해당 디렉토리가 없으면
                if not os.path.isdir(dir_name):
                    #디렉토리를 생성
                    os.makedirs(dir_name)

                #해당 url에서 파일명만 추출
                #file_name = os.path.basename(mp3_url)
                clean_title = clean_text(title)
                file_name = f'{clean_title}.mp3'
                #생성된 디렉토리명과 파일명을 합쳐주기
                file_name = os.path.join(dir_name, file_name)           
                #print(file_name)

                res = requests.get(mp3_url, headers=req_header)
                if res.ok:
                    #response 객체에서 binary 데이터 추출
                    mp3_bin = res.content                
                    #binary 데이터를 local 파일로 저장
                    with open(file_name, 'wb') as file:
                        file.write(mp3_bin)

# %%
podbbang_download(15357,'반란의영문법')
# Out:
# 200
# 20
# ------
# [유튜브 강의 오디오 버전] 명사의 종류 https://file.ssenhosting.com/data1/pb_20454/KL02nountypes.mp3?cmad=2f64617461312f70625f32303435342f4b4c30326e6f756e74797065735f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] of는 물리적 변화, from은 화학적 변화?? https://file.ssenhosting.com/data1/pb_20454/KL01fromof.mp3?cmad=2f64617461312f70625f32303435342f4b4c303166726f6d6f665f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 10. 가정법 개념 정리 - 한국과 영어권의 차이 https://file.ssenhosting.com/data1/pb_20454/subjunctive10.mp3?cmad=2f64617461312f70625f32303435342f7375626a756e637469766531305f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 9. If ... will ... (if 조건절에 will이 쓰이는 경우들) https://file.ssenhosting.com/data1/pb_20454/condi009.mp3?cmad=2f64617461312f70625f32303435342f636f6e64693030395f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 8. as if와 I wish - 한국어와 표현 방식이 같은데 오히려 어려운 이유 https://file.ssenhosting.com/data1/pb_20454/backshift08.mp3?cmad=2f64617461312f70625f32303435342f6261636b736869667430385f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 7. unless와 if...not... (공통점과 차이점) https://file.ssenhosting.com/data1/pb_20454/7unlessifnot.mp3?cmad=2f64617461312f70625f32303435342f37756e6c65737369666e6f745f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 6. 미래 조건문 - 이른바 "가정법 미래"의 숨겨진 진실 https://file.ssenhosting.com/data1/pb_20454/6futureconditional.mp3?cmad=2f64617461312f70625f32303435342f36667574757265636f6e646974696f6e616c5f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 5. 비현실적 조건문 - 가장 어려워 하는 이른바 "가정법 문장" https://file.ssenhosting.com/data1/pb_20454/5unrealconditional.mp3?cmad=2f64617461312f70625f32303435342f35756e7265616c636f6e646974696f6e616c5f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 4. 현실적 조건문 - 한국식 영문법에 없는 past real conditional https://file.ssenhosting.com/data1/pb_20454/4realconditional.mp3?cmad=2f64617461312f70625f32303435342f347265616c636f6e646974696f6e616c5f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 3. 가정법과 조건문 - 이상한 한국식 용어들 https://file.ssenhosting.com/data1/pb_20454/3conditionalss.mp3?cmad=2f64617461312f70625f32303435342f33636f6e646974696f6e616c73735f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 2. 영어에 정말로 가정법이 있는가? https://file.ssenhosting.com/data1/pb_20454/2istheresubjunctive.mp3?cmad=2f64617461312f70625f32303435342f32697374686572657375626a756e63746976655f6133312e6d7033
# ------
# [유튜브 강의 오디오 버전] 1. 가정법이 도대체 무엇일까? https://file.ssenhosting.com/data1/pb_20454/whatisthesubjunctive.mp3?cmad=2f64617461312f70625f32303435342f7768617469737468657375626a756e63746976655f76325f6133312e6d7033
# ------
# 가정법 Q&A - I wish, as if https://file.ssenhosting.com/data1/pb_20454/asifiwish.mp3?cmad=2f64617461312f70625f32303435342f6173696669776973685f6133312e6d7033
# ------
# 가정법 Q&A - 과거에 대한 현실적 조건문 https://file.ssenhosting.com/data1/pb_20454/pastrealcondition.mp3?cmad=2f64617461312f70625f32303435342f706173747265616c636f6e646974696f6e5f6133312e6d7033
# ------
# 가정법 Q&A - 가정법 미래 https://file.ssenhosting.com/data1/pb_20454/futurecondi.mp3?cmad=2f64617461312f70625f32303435342f667574757265636f6e64695f6133312e6d7033
# ------
# 다들 아는 척하지만 사실은 모르고 있는 영문법 이야기 - 조건문 https://file.ssenhosting.com/data1/pb_20454/conditionalbackshift01.mp3?cmad=2f64617461312f70625f32303435342f636f6e646974696f6e616c6261636b736869667430315f76325f6133312e6d7033
# ------
# 다들 아는 척하지만 사실은 모르고 있는 영문법 이야기 - 가정법 https://file.ssenhosting.com/data1/pb_20454/subjunct1.mp3?cmad=2f64617461312f70625f32303435342f7375626a756e6374315f76335f6133312e6d7033
# ------
# 120. 생략, 동격, 부정 - He is no doctor. vs. He is not a doctor. https://file.ssenhosting.com/data1/pb_20454/rebelgrammar120.mp3?cmad=2f64617461312f70625f32303435342f726562656c6772616d6d61723132305f6133312e6d7033
# ------
# 119. 강조 - "To be or not to be, that is the question." 주어가 2개여도 되나? https://file.ssenhosting.com/data1/pb_20454/rebelgrammar119.mp3?cmad=2f64617461312f70625f32303435342f726562656c6772616d6d61723131395f6133312e6d7033
# ------
# 118. 도치 - 초점 주고 박자 맞추기 https://file.ssenhosting.com/data1/pb_20454/rebelgrammar118.mp3?cmad=2f64617461312f70625f32303435342f726562656c6772616d6d61723131385f76325f6133312e6d7033

# %% [markdown]
# ### 팟빵 다운로드 3단계
# * 채널의 id 와 제목을 함수의 인자로 받는다.
# * 저장되는 mp3 파일명을 에피소드의 타이틀로 설정한다.
# * 모든 에피소드를 다운로드 받는다.
# * 에피소드를 요청할때 offset 값의 최대값이 항상 변하므로 itertools의 count() 함수를 사용해 무한루프를 수행하도록 한다.
#   - 무한루프를 빠져 나올수 있는 조건식을 반드시 주어야 한다.
#   - json_data['data'] 길이가 0 이면 무한루프를 탈출한다.
# * 사람이 직접 다운로드 받는 것 처럼 보이게 하기 위해서 sleep time 설정한다.
#   - time 이라는 내부모듈의 sleep 함수를 사용한다.수를 사용한다.수를 사용한다.

# %%
def podbbang_all_download(channel_id, channel_title):
    import requests
    from bs4 import BeautifulSoup
    from urllib.parse import urljoin
    import json
    import os
    from itertools import count
    from time import sleep
    
    url = f'https://app-api6.podbbang.com/channels/{channel_id}/episodes'
    for offset in count(0):
        req_param = {
            "offset":offset,
            "limit":20,
            "sort":"desc",
            "episode_id":0,
            "focus_center":0,
            "with":"image"        
        }

        res = requests.get(url, params=req_param)
        print(offset, res.status_code)
        if res.ok:
            json_data = res.json()    
            #{data:[{},{},{}]}
            episode_list = json_data['data']
            print(len(episode_list))

            # 무한루프 탈출 조건
            if len(json_data['data']) == 0:
               break                 
                
            for episode in episode_list:
                print('------')
                #에피소드의 제목
                title = episode['title']
                #에피소드 다운로드 url
                mp3_url = episode['media']['url']
                print(title, mp3_url)

                #url 값이 있으면 다운로드 받아야 함
                if mp3_url:            
                    req_header = {
                        'referer':f'https://www.podbbang.com/channels/{channel_id}',
                        'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36'
                    }

                    if not os.path.isdir('mp3'):
                        os.mkdir('mp3')

                    dir_name = os.path.join('mp3',channel_title)
                    #print(dir_name) #mp3\미드처방전

                    #해당 디렉토리가 없으면
                    if not os.path.isdir(dir_name):
                        #디렉토리를 생성
                        os.makedirs(dir_name)

                    clean_title = clean_text(title)
                    file_name = f'{clean_title}.mp3'
                    #생성된 디렉토리명과 파일명을 합쳐주기
                    file_name = os.path.join(dir_name, file_name)           
                    #print(file_name)

                    res = requests.get(mp3_url, headers=req_header)
                    if res.ok:
                        #response 객체에서 binary 데이터 추출
                        mp3_bin = res.content                
                        #binary 데이터를 local 파일로 저장
                        with open(file_name, 'wb') as file:
                            file.write(mp3_bin)
                            
                        #0.5초간 프로세스를 중지함, 기계가 아니라 사람처럼 보이게 하려고
                        sleep(0.5)

# %%
podbbang_all_download('16255','여바라')
# Out:
# 0 200
# 20
# ------
# 46. 소소하게 여행중독 #2 : 문상건 작가의 아시아와 세이셸 https://file.ssenhosting.com/data1/pb_21610/yeovara46.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726134365f6133312e6d7033
# ------
# 45. 소소하게 여행중독 - 문상건 작가의 인도 여행기 https://file.ssenhosting.com/data1/pb_21610/yeovara45.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726134355f6133312e6d7033
# ------
# 44. 여행직업탐구 : 국외여행인솔자 뽀개기 feat. 서주희 https://file.ssenhosting.com/data1/pb_21610/yeovara44.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726134345f6133312e6d7033
# ------
# 43. 코이카(KOICA) 뽀개기 feat.서주희 https://file.ssenhosting.com/data1/pb_21610/yeovara43.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726134335f6133312e6d7033
# ------
# 42. 6개월 동안의 신혼여행 feat 밤송이 https://file.ssenhosting.com/data1/pb_21610/yeovara42.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726134325f6133312e6d7033
# ------
# 춤추는 쥬디의 플래시몹 in 멕시코시티 https://file.ssenhosting.com/data1/pb_21610/mexico.mp4
# ------
# 41. 춤추는 쥬디의 멕시코 여행 https://file.ssenhosting.com/data1/pb_21610/yeovara41.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726134315f6133312e6d7033
# ------
# 40. 여행하다 배우다 : 남미에서 살사, 스페인어 정복하기 feat. 쥬디 https://file.ssenhosting.com/data1/pb_21610/yeovara40.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726134305f6133312e6d7033
# ------
# 39. 불의 나라 아제르바이잔, 바람의 도시 바쿠 feat 바쿠소녀 송의영 https://file.ssenhosting.com/data1/pb_21610/yeovara39.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726133395f6133312e6d7033
# ------
# 38. 조지아(Georgia)를 아시나요? feat 바쿠소녀 송의영 https://file.ssenhosting.com/data1/pb_21610/yeovara38.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726133385f76325f6133312e6d7033
# ------
# 37. 세계의 지붕 파미르 고원을 넘다(키르기스스탄, 타지키스탄) - 자전거 여행가 김상아 https://file.ssenhosting.com/data1/pb_21610/yeovara37.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726133375f6133312e6d7033
# ------
# 36. 퇴사하고 자전거 세계여행 - 첫 나라 인도 feat 김상아 https://file.ssenhosting.com/data1/pb_21610/yeovara36.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726133365f6133312e6d7033
# ------
# 35. 그 남자, 그 여자의 아프리카 feat. 보혜, 현 커플 https://file.ssenhosting.com/data1/pb_21610/35MASTER.mp3?cmad=2f64617461312f70625f32313631302f33354d41535445525f76325f6133312e6d7033
# ------
# 34. 여행하다 연애하다 - 강보혜, 이현 커플 https://file.ssenhosting.com/data1/pb_21610/yeovara34.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726133345f6133312e6d7033
# ------
# 여바라 댓글 이벤트 당첨자 발표!! https://file.ssenhosting.com/data1/pb_21610/gramonevent.mp4
# ------
# 33. 도전을 도전한다 2부 - 오바마를 찾아서 feat. 박재병 https://file.ssenhosting.com/data1/pb_21610/yeovara33.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726133335f6133312e6d7033
# ------
# 32. 도전을 도전한다 1부 - 호세 무히카를 만나다 feat. 박재병 https://file.ssenhosting.com/data1/pb_21610/yeovara32.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726133325f6133312e6d7033
# ------
# 31. 노숙자의 삶이 궁금해서 노숙자가 돼봤어요 feat. 박재병 https://file.ssenhosting.com/data1/pb_21610/yeovara31.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726133315f6133312e6d7033
# ------
# 30. 내가 걸어가는 내 모습을 바라본다 - 변종모 작가 https://file.ssenhosting.com/data1/pb_21610/yeovara30.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726133305f6133312e6d7033
# ------
# 29. 아무 것도 하고 싶지 않다 격렬히 아무 것도 하고 싶지 않다 - 변종모 작가 https://file.ssenhosting.com/data1/pb_21610/yeovara29.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132395f6133312e6d7033
# 1 200
# 20
# ------
# 28. 히치하이킹, 세상에서 가장 아름다운 교통수단 - 타박타박 영연 https://file.ssenhosting.com/data1/pb_21610/yeovara28.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132385f6133312e6d7033
# ------
# 27. 5만원으로 떠난 노르웨이 - 타박타박 최영연 https://file.ssenhosting.com/data1/pb_21610/yeovara27.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132375f6133312e6d7033
# ------
# 26. 총맞은 여행가 임효선의 값비싼 전화위복기 https://file.ssenhosting.com/data1/pb_21610/yeovara26.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132365f6133312e6d7033
# ------
# 번외클립 설계자들 : 인도 최저가 여행 https://file.ssenhosting.com/data1/pb_21610/extra26.mp3?cmad=2f64617461312f70625f32313631302f657874726132365f6133312e6d7033
# ------
# 25. 총맞은 여행가 임효선의 좌충우돌 초보여행기 https://file.ssenhosting.com/data1/pb_21610/yeovara25.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132355f6133312e6d7033
# ------
# 24. 여행은 살아보는 거야 feat 방콕러 박민우 https://file.ssenhosting.com/data1/pb_21610/yeovara24.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132345f6133312e6d7033
# ------
# 23. 이십년차 배낭여행자의 생존법 - 찌질왕 박민우 https://file.ssenhosting.com/data1/pb_21610/yeovara23.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132335f6133312e6d7033
# ------
# 22. 협찬 여행을 알려주마 : 열정여행가 김훈호 https://file.ssenhosting.com/data1/pb_21610/yeovara22.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132325f6133312e6d7033
# ------
# 21. 알래스카부터 아르헨티나까지, 열정 여행가 김훈호 작가의 자전거 여행도전기 https://file.ssenhosting.com/data1/pb_21610/yeovara21.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132315f6133312e6d7033
# ------
# 20. 파키스탄 훈자 : 산도 타고, 썸도 타고 + 훈자여행 막간 팁 https://file.ssenhosting.com/data1/pb_21610/yeovara20.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726132305f6133312e6d7033
# ------
# 19. 파키스탄 훈자 : 군용 헬기와 비행기 탄 썰 (feat. 이상호기자) https://file.ssenhosting.com/data1/pb_21610/yeovara19.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726131395f6133312e6d7033
# ------
# 18. 힐링 여행 추천 두번째 이야기 : 파키스탄 훈자로 가는 길 https://file.ssenhosting.com/data1/pb_21610/yeovara18.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726131385f6133312e6d7033
# ------
# 17. 인생의 쉼표, 자전거와 바이크로 바라본 또바호수 3부 https://file.ssenhosting.com/data1/pb_21610/17yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f313779656f766172614d61737465725f76325f6133312e6d7033
# ------
# 16. 휴양지 가성비의 끝판왕 : 인도네시아 또바호수 2부 https://file.ssenhosting.com/data1/pb_21610/16yeovaramater.mp3?cmad=2f64617461312f70625f32313631302f313679656f766172616d617465725f6133312e6d7033
# ------
# 15. 힐링여행 : 인도네시아의 숨은 보석 또바호수 1부 https://file.ssenhosting.com/data1/pb_21610/yeovara15.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726131355f6133312e6d7033
# ------
# 번외클립#3 장기배낭여행꿀팁 : 가벼운 배낭을 위한 제안 https://file.ssenhosting.com/data1/pb_21610/extra03master.mp3?cmad=2f64617461312f70625f32313631302f657874726130336d61737465725f76325f6133312e6d7033
# ------
# 번외클립#2 장기배낭여행꿀팁 : 숙소, 이제 입맛대로 고르자 https://file.ssenhosting.com/data1/pb_21610/extra02master.mp3?cmad=2f64617461312f70625f32313631302f657874726130326d61737465725f6133312e6d7033
# ------
# 번외클립#1 장기배낭여행꿀팁 : 취향별 항공권 구입방법 https://file.ssenhosting.com/data1/pb_21610/extra01master.mp3?cmad=2f64617461312f70625f32313631302f657874726130316d61737465725f76335f6133312e6d7033
# ------
# 14. 본격 일본 교토 카페 탐방 + 설계자들 베트남 다낭 https://file.ssenhosting.com/data1/pb_21610/yeovara14.mp3?cmad=2f64617461312f70625f32313631302f79656f7661726131345f6133312e6d7033
# ------
# 13. 일본 교토 남부 : 우지, 마차의 맛 https://file.ssenhosting.com/data1/pb_21610/13yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f313379656f766172614d61737465725f6133312e6d7033
# 2 200
# 12
# ------
# 12. 일본 교토, 벚꽃엔딩 : 킨카쿠지, 료안지, 니조조 https://file.ssenhosting.com/data1/pb_21610/12yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f313279656f766172614d61737465725f76325f6133312e6d7033
# ------
# 11. 일본 오사카, 유니버설 스튜디오 재팬으로 무브무브! + 본격! 장기여행 배낭싸기 노하우 https://file.ssenhosting.com/data1/pb_21610/11yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f313179656f766172614d61737465725f6133312e6d7033
# ------
# 10. 중국인이 사는 태국 마을 : 도이매싸롱 + 숙소구하기 꿀팁 https://file.ssenhosting.com/data1/pb_21610/10yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f313079656f766172614d61737465725f6133312e6d7033
# ------
# 9. 태국 : '난' 정말 그대 그대만을 좋아했어 https://file.ssenhosting.com/data1/pb_21610/09yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f303979656f766172614d61737465725f6133312e6d7033
# ------
# 8. 태국의 빠리, 치앙마이 & 밍이 만난 사람들, 람빵 https://file.ssenhosting.com/data1/pb_21610/08yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f303879656f766172614d61737465725f6133312e6d7033
# ------
# 7. 태국의 빠리, 치앙마이 3부 + 설계자들 카우치서핑 https://file.ssenhosting.com/data1/pb_21610/07yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f303779656f766172614d61737465725f6133312e6d7033
# ------
# 6. 태국의 빠리, 치앙마이 2부 치앙마이 친구들 룽랑, 임이 알려드립니다 https://file.ssenhosting.com/data1/pb_21610/06yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f303679656f766172614d61737465725f6133312e6d7033
# ------
# 5. 태국의 빠리, 치앙마이 1부 + 설계자들 인도 최저가 여행 https://file.ssenhosting.com/data1/pb_21610/05yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f303579656f766172614d61737465725f6133312e6d7033
# ------
# 4. 라오스 : 욕망이 멈췄던 곳 3부 폰사완, 루앙프라방, 루앙남타 https://file.ssenhosting.com/data1/pb_21610/04yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f303479656f766172614d61737465725f6133312e6d7033
# ------
# 3. 라오스 : 욕망이 멈췄던 곳 2부 방비엥 + 설계자들 미얀마 https://file.ssenhosting.com/data1/pb_21610/03yeovaraMaster.mp3?cmad=2f64617461312f70625f32313631302f303379656f766172614d61737465725f6133312e6d7033
# ------
# 2. 라오스 : 욕망이 멈췄던 곳 1부 비엔티안, 방비엥 + 취향별 항공권 구입방법 https://file.ssenhosting.com/data1/pb_21610/02remaster.mp3?cmad=2f64617461312f70625f32313631302f303272656d61737465725f76325f6133312e6d7033
# ------
# 1. 프롤로그:장기 배낭 여행의 시작, 여바라행 편도 티켓 https://file.ssenhosting.com/data1/pb_21610/yeovara0.mp3?cmad=2f64617461312f70625f32313631302f79656f76617261305f6133312e6d7033
# 3 200
# 0
