# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
primary = pd.read_csv("data/2016_presidential_election/primary_results.csv",sep=",")
counties = pd.read_csv("data/2016_presidential_election/county_facts.csv",sep=",")

# %%
print(primary.shape)	#라인수, 컬럼수 확인
print(primary.columns) 	#컬럼명 확인
primary.head()	#상위 5개 행의 데이터 확인
# Out:
# (13212, 8)
# Index(['state', 'state_abbreviation', 'county', 'fips', 'party', 'candidate',
#        'votes', 'fraction_votes'],
#       dtype='object')
#      state state_abbreviation   county  fips       party     candidate  votes  \
# 0  Alabama                 AL  Autauga  1001  Republican  Donald Trump   5387
# 1  Alabama                 AL  Autauga  1001  Republican      Ted Cruz   2482
# 2  Alabama                 AL  Autauga  1001  Republican   Marco Rubio   1785
# 3  Alabama                 AL  Autauga  1001  Republican    Ben Carson   1764
# 4  Alabama                 AL  Autauga  1001  Republican   John Kasich    421
#
#    fraction_votes
# 0           0.445
# 1           0.205
# 2           0.148
# 3           0.146
# 4           0.035

# %%
primary['party'].unique()
# Out:
# array(['Republican', 'Democrat'], dtype=object)

# %%
print(counties.shape)
print(counties.columns)
counties.head()
# Out:
# (3195, 54)
# Index(['fips', 'area_name', 'state_abbreviation', 'PST045214', 'PST040210',
#        'PST120214', 'POP010210', 'AGE135214', 'AGE295214', 'AGE775214',
#        'SEX255214', 'RHI125214', 'RHI225214', 'RHI325214', 'RHI425214',
#        'RHI525214', 'RHI625214', 'RHI725214', 'RHI825214', 'POP715213',
#        'POP645213', 'POP815213', 'EDU635213', 'EDU685213', 'VET605213',
#        'LFE305213', 'HSG010214', 'HSG445213', 'HSG096213', 'HSG495213',
#        'HSD410213', 'HSD310213', 'INC910213', 'INC110213', 'PVY020213',
#        'BZA010213', 'BZA110213', 'BZA115213', 'NES010213', 'SBO001207',
#        'SBO315207', 'SBO115207', 'SBO215207', 'SBO515207', 'SBO415207',
#        'SBO015207', 'MAN450207', 'WTN220207', 'RTN130207', 'RTN131207',
#        'AFN120207', 'BPS030214', 'LND110210', 'POP060210'],
#       dtype='object')
#    fips       area_name state_abbreviation  PST045214  PST040210  PST120214  \
# 0     0   United States                NaN  318857056  308758105        3.3
# 1  1000         Alabama                NaN    4849377    4780127        1.4
# 2  1001  Autauga County                 AL      55395      54571        1.5
# 3  1003  Baldwin County                 AL     200111     182265        9.8
# 4  1005  Barbour County                 AL      26887      27457       -2.1
#
#    POP010210  AGE135214  AGE295214  AGE775214  ...  SBO415207  SBO015207  \
# 0  308745538        6.2       23.1       14.5  ...        8.3       28.8
# 1    4779736        6.1       22.8       15.3  ...        1.2       28.1
# 2      54571        6.0       25.2       13.8  ...        0.7       31.7
# 3     182265        5.6       22.2       18.7  ...        1.3       27.3
# 4      27457        5.7       21.2       16.5  ...        0.0       27.0
#
#     MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  BPS030214  \
# 0  5319456312  4174286516  3917663456      12990  613795732    1046363
# 1   112858843    52252752    57344851      12364    6426342      13369
# 2           0           0      598175      12003      88157        131
# 3     1410273           0     2966489      17166     436955       1384
# 4           0           0      188337       6334          0          8
#
#     LND110210  POP060210
# 0  3531905.43       87.4
# 1    50645.33       94.4
# 2      594.44       91.8
# 3     1589.78      114.6
# 4      884.88       31.0
#
# [5 rows x 54 columns]

# %% [markdown]
# ### 각 후보별 전체 득표수 계산하기

# %%
candidate_to_votes_s = primary.groupby("candidate")["votes"].sum().sort_values()

# %%
candidate_to_votes_s
# Out:
# candidate
#  Uncommitted            43
#  No Preference         313
# Martin O'Malley        747
# Rick Santorum         1773
# Mike Huckabee         3300
# Rand Paul             8460
# Carly Fiorina        15181
# Chris Christie       24347
# Jeb Bush             94394
# Ben Carson          528463
# John Kasich        2456406
# Marco Rubio        2998335
# Bernie Sanders     4740278
# Ted Cruz           5248807
# Donald Trump       6944654
# Hillary Clinton    7178257
# Name: votes, dtype: int64

# %%
plt.figure(figsize=(20,10))
candidate_to_votes_s.plot(kind="barh", fontsize=8)
# Out:
# <AxesSubplot:ylabel='candidate'>

# %% [markdown]
# ### 각 주별, 각 정당의 득표 비율 계산하기
# ### 각 주별, 정당별 득표수 계산하기

# %%
state_party_to_votes_s = primary.groupby(["state", "party"])["votes"].sum()
state_party_to_votes_s
# Out:
# state           party
# Alabama         Democrat       381810
#                 Republican     805814
# Arizona         Democrat       399097
#                 Republican     435103
# Arkansas        Democrat       207182
#                 Republican     395108
# Colorado        Democrat       121184
# Florida         Democrat      1611617
#                 Republican    2156298
# Georgia         Democrat       642420
#                 Republican    1232089
# Idaho           Democrat        23567
#                 Republican     211484
# Illinois        Democrat       658976
#                 Republican     881888
# Iowa            Democrat       139682
#                 Republican     185508
# Kentucky        Republican     225709
# Louisiana       Democrat       256849
#                 Republican     240017
# Maine           Democrat          101
# Massachusetts   Democrat        51613
#                 Republican      31517
# Michigan        Democrat      1159586
#                 Republican    1227909
# Mississippi     Democrat       209439
#                 Republican     368296
# Missouri        Democrat       350507
#                 Republican     680795
# Nebraska        Democrat        33460
# Nevada          Democrat        11937
#                 Republican      74878
# New Hampshire   Democrat       246836
#                 Republican     279130
# North Carolina  Democrat      1075209
#                 Republican    1104814
# Ohio            Democrat      1192815
#                 Republican    2011357
# Oklahoma        Democrat       309611
#                 Republican     449729
# South Carolina  Democrat       367491
#                 Republican     737917
# Tennessee       Democrat       364710
#                 Republican     832492
# Texas           Democrat      1396514
#                 Republican    2695138
# Utah            Democrat        76999
#                 Republican     177204
# Vermont         Democrat        11966
#                 Republican       6255
# Virginia        Democrat       618460
#                 Republican     877671
# Name: votes, dtype: int64

# %%
#각 주별 득표수
state_to_votes_s = primary.groupby("state")["votes"].sum()
state_to_votes_s
# Out:
# state
# Alabama           1187624
# Arizona            834200
# Arkansas           602290
# Colorado           121184
# Florida           3767915
# Georgia           1874509
# Idaho              235051
# Illinois          1540864
# Iowa               325190
# Kentucky           225709
# Louisiana          496866
# Maine                 101
# Massachusetts       83130
# Michigan          2387495
# Mississippi        577735
# Missouri          1031302
# Nebraska            33460
# Nevada              86815
# New Hampshire      525966
# North Carolina    2180023
# Ohio              3204172
# Oklahoma           759340
# South Carolina    1105408
# Tennessee         1197202
# Texas             4091652
# Utah               254203
# Vermont             18221
# Virginia          1496131
# Name: votes, dtype: int64

# %% [markdown]
# ### state별, party별 득표수의 합의 퍼센티지 구함

# %%
state_party_to_vote_pcts_s = state_party_to_votes_s / state_to_votes_s
state_party_to_vote_pcts_s
# Out:
# state           party
# Alabama         Democrat      0.321491
#                 Republican    0.678509
# Arizona         Democrat      0.478419
#                 Republican    0.521581
# Arkansas        Democrat      0.343990
#                 Republican    0.656010
# Colorado        Democrat      1.000000
# Florida         Democrat      0.427721
#                 Republican    0.572279
# Georgia         Democrat      0.342714
#                 Republican    0.657286
# Idaho           Democrat      0.100263
#                 Republican    0.899737
# Illinois        Democrat      0.427667
#                 Republican    0.572333
# Iowa            Democrat      0.429540
#                 Republican    0.570460
# Kentucky        Republican    1.000000
# Louisiana       Democrat      0.516938
#                 Republican    0.483062
# Maine           Democrat      1.000000
# Massachusetts   Democrat      0.620871
#                 Republican    0.379129
# Michigan        Democrat      0.485691
#                 Republican    0.514309
# Mississippi     Democrat      0.362517
#                 Republican    0.637483
# Missouri        Democrat      0.339868
#                 Republican    0.660132
# Nebraska        Democrat      1.000000
# Nevada          Democrat      0.137499
#                 Republican    0.862501
# New Hampshire   Democrat      0.469300
#                 Republican    0.530700
# North Carolina  Democrat      0.493210
#                 Republican    0.506790
# Ohio            Democrat      0.372269
#                 Republican    0.627731
# Oklahoma        Democrat      0.407737
#                 Republican    0.592263
# South Carolina  Democrat      0.332448
#                 Republican    0.667552
# Tennessee       Democrat      0.304635
#                 Republican    0.695365
# Texas           Democrat      0.341308
#                 Republican    0.658692
# Utah            Democrat      0.302904
#                 Republican    0.697096
# Vermont         Democrat      0.656715
#                 Republican    0.343285
# Virginia        Democrat      0.413373
#                 Republican    0.586627
# Name: votes, dtype: float64

# %%
print(type(state_party_to_vote_pcts_s))
print(state_party_to_vote_pcts_s.index)
# Out:
# <class 'pandas.core.series.Series'>
# MultiIndex([(       'Alabama',   'Democrat'),
#             (       'Alabama', 'Republican'),
#             (       'Arizona',   'Democrat'),
#             (       'Arizona', 'Republican'),
#             (      'Arkansas',   'Democrat'),
#             (      'Arkansas', 'Republican'),
#             (      'Colorado',   'Democrat'),
#             (       'Florida',   'Democrat'),
#             (       'Florida', 'Republican'),
#             (       'Georgia',   'Democrat'),
#             (       'Georgia', 'Republican'),
#             (         'Idaho',   'Democrat'),
#             (         'Idaho', 'Republican'),
#             (      'Illinois',   'Democrat'),
#             (      'Illinois', 'Republican'),
#             (          'Iowa',   'Democrat'),
#             (          'Iowa', 'Republican'),
#             (      'Kentucky', 'Republican'),
#             (     'Louisiana',   'Democrat'),
#             (     'Louisiana', 'Republican'),
#             (         'Maine',   'Democrat'),
#             ( 'Massachusetts',   'Democrat'),
#             ( 'Massachusetts', 'Republican'),
#             (      'Michigan',   'Democrat'),
#             (      'Michigan', 'Republican'),
#             (   'Mississippi',   'Democrat'),
#             (   'Mississippi', 'Republican'),
#             (      'Missouri',   'Democrat'),
#             (      'Missouri', 'Republican'),
#             (      'Nebraska',   'Democrat'),
#             (        'Nevada',   'Democrat'),
#             (        'Nevada', 'Republican'),
#             ( 'New Hampshire',   'Democrat'),
#             ( 'New Hampshire', 'Republican'),
#             ('North Carolina',   'Democrat'),
#             ('North Carolina', 'Republican'),
#             (          'Ohio',   'Democrat'),
#             (          'Ohio', 'Republican'),
#             (      'Oklahoma',   'Democrat'),
#             (      'Oklahoma', 'Republican'),
#             ('South Carolina',   'Democrat'),
#             ('South Carolina', 'Republican'),
#             (     'Tennessee',   'Democrat'),
#             (     'Tennessee', 'Republican'),
#             (         'Texas',   'Democrat'),
#             (         'Texas', 'Republican'),
#             (          'Utah',   'Democrat'),
#             (          'Utah', 'Republican'),
#             (       'Vermont',   'Democrat'),
#             (       'Vermont', 'Republican'),
#             (      'Virginia',   'Democrat'),
#             (      'Virginia', 'Republican')],
#            names=['state', 'party'])

# %%
#인덱스로 되어 있던 party(정당) : 인덱스를 칼럼으로 보낸것임 - 최하위 인덱스를 칼럼으로 보냄
state_party_to_vote_pcts_df = state_party_to_vote_pcts_s.unstack()
state_party_to_vote_pcts_df
# Out:
# party           Democrat  Republican
# state
# Alabama         0.321491    0.678509
# Arizona         0.478419    0.521581
# Arkansas        0.343990    0.656010
# Colorado        1.000000         NaN
# Florida         0.427721    0.572279
# Georgia         0.342714    0.657286
# Idaho           0.100263    0.899737
# Illinois        0.427667    0.572333
# Iowa            0.429540    0.570460
# Kentucky             NaN    1.000000
# Louisiana       0.516938    0.483062
# Maine           1.000000         NaN
# Massachusetts   0.620871    0.379129
# Michigan        0.485691    0.514309
# Mississippi     0.362517    0.637483
# Missouri        0.339868    0.660132
# Nebraska        1.000000         NaN
# Nevada          0.137499    0.862501
# New Hampshire   0.469300    0.530700
# North Carolina  0.493210    0.506790
# Ohio            0.372269    0.627731
# Oklahoma        0.407737    0.592263
# South Carolina  0.332448    0.667552
# Tennessee       0.304635    0.695365
# Texas           0.341308    0.658692
# Utah            0.302904    0.697096
# Vermont         0.656715    0.343285
# Virginia        0.413373    0.586627

# %%
print(type(state_party_to_vote_pcts_df))
print(state_party_to_vote_pcts_df.index)
print(state_party_to_vote_pcts_df.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['Alabama', 'Arizona', 'Arkansas', 'Colorado', 'Florida', 'Georgia',
#        'Idaho', 'Illinois', 'Iowa', 'Kentucky', 'Louisiana', 'Maine',
#        'Massachusetts', 'Michigan', 'Mississippi', 'Missouri', 'Nebraska',
#        'Nevada', 'New Hampshire', 'North Carolina', 'Ohio', 'Oklahoma',
#        'South Carolina', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia'],
#       dtype='object', name='state')
# Index(['Democrat', 'Republican'], dtype='object', name='party')

# %%
figure, axes1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,12)
#plt.figure(figsize=(100,40))
state_party_to_vote_pcts_df.plot(kind="barh", stacked=True, fontsize=10, ax=axes1)
# Out:
# <AxesSubplot:ylabel='state'>

# %% [markdown]
# ## primary와 counties 를 merge하는 연습하기

# %%
#merge 연습 fips 칼럼 기준으로 merge
pd.merge(primary, counties, on="fips")
# Out:
#                state state_abbreviation_x    county   fips       party  \
# 0            Alabama                   AL   Autauga   1001  Republican
# 1            Alabama                   AL   Autauga   1001  Republican
# 2            Alabama                   AL   Autauga   1001  Republican
# 3            Alabama                   AL   Autauga   1001  Republican
# 4            Alabama                   AL   Autauga   1001  Republican
# ...              ...                  ...       ...    ...         ...
# 13207  New Hampshire                   NH  Sullivan  33019  Republican
# 13208  New Hampshire                   NH  Sullivan  33019  Republican
# 13209  New Hampshire                   NH  Sullivan  33019  Republican
# 13210  New Hampshire                   NH  Sullivan  33019  Republican
# 13211  New Hampshire                   NH  Sullivan  33019  Republican
#
#           candidate  votes  fraction_votes        area_name  \
# 0      Donald Trump   5387        0.445000   Autauga County
# 1          Ted Cruz   2482        0.205000   Autauga County
# 2       Marco Rubio   1785        0.148000   Autauga County
# 3        Ben Carson   1764        0.146000   Autauga County
# 4       John Kasich    421        0.035000   Autauga County
# ...             ...    ...             ...              ...
# 13207  Donald Trump   3080        0.380952  Sullivan County
# 13208      Jeb Bush    824        0.101917  Sullivan County
# 13209   John Kasich   1334        0.164997  Sullivan County
# 13210   Marco Rubio    895        0.110699  Sullivan County
# 13211      Ted Cruz    951        0.117625  Sullivan County
#
#       state_abbreviation_y  ...  SBO415207  SBO015207  MAN450207  WTN220207  \
# 0                       AL  ...        0.7       31.7          0          0
# 1                       AL  ...        0.7       31.7          0          0
# 2                       AL  ...        0.7       31.7          0          0
# 3                       AL  ...        0.7       31.7          0          0
# 4                       AL  ...        0.7       31.7          0          0
# ...                    ...  ...        ...        ...        ...        ...
# 13207                   NH  ...        0.0       24.8     640776          0
# 13208                   NH  ...        0.0       24.8     640776          0
# 13209                   NH  ...        0.0       24.8     640776          0
# 13210                   NH  ...        0.0       24.8     640776          0
# 13211                   NH  ...        0.0       24.8     640776          0
#
#        RTN130207  RTN131207  AFN120207  BPS030214  LND110210  POP060210
# 0         598175      12003      88157        131     594.44       91.8
# 1         598175      12003      88157        131     594.44       91.8
# 2         598175      12003      88157        131     594.44       91.8
# 3         598175      12003      88157        131     594.44       91.8
# 4         598175      12003      88157        131     594.44       91.8
# ...          ...        ...        ...        ...        ...        ...
# 13207     562392      13154      32307         53     537.31       81.4
# 13208     562392      13154      32307         53     537.31       81.4
# 13209     562392      13154      32307         53     537.31       81.4
# 13210     562392      13154      32307         53     537.31       81.4
# 13211     562392      13154      32307         53     537.31       81.4
#
# [13212 rows x 61 columns]

# %%
#primary의 모든 컬럼과 counties의 'fips'와 'RHI425214' 컬럼  join
pd.merge(primary, counties[['fips','RHI425214']], on="fips")
# Out:
#                state state_abbreviation    county   fips       party  \
# 0            Alabama                 AL   Autauga   1001  Republican
# 1            Alabama                 AL   Autauga   1001  Republican
# 2            Alabama                 AL   Autauga   1001  Republican
# 3            Alabama                 AL   Autauga   1001  Republican
# 4            Alabama                 AL   Autauga   1001  Republican
# ...              ...                ...       ...    ...         ...
# 13207  New Hampshire                 NH  Sullivan  33019  Republican
# 13208  New Hampshire                 NH  Sullivan  33019  Republican
# 13209  New Hampshire                 NH  Sullivan  33019  Republican
# 13210  New Hampshire                 NH  Sullivan  33019  Republican
# 13211  New Hampshire                 NH  Sullivan  33019  Republican
#
#           candidate  votes  fraction_votes  RHI425214
# 0      Donald Trump   5387        0.445000        1.1
# 1          Ted Cruz   2482        0.205000        1.1
# 2       Marco Rubio   1785        0.148000        1.1
# 3        Ben Carson   1764        0.146000        1.1
# 4       John Kasich    421        0.035000        1.1
# ...             ...    ...             ...        ...
# 13207  Donald Trump   3080        0.380952        0.7
# 13208      Jeb Bush    824        0.101917        0.7
# 13209   John Kasich   1334        0.164997        0.7
# 13210   Marco Rubio    895        0.110699        0.7
# 13211      Ted Cruz    951        0.117625        0.7
#
# [13212 rows x 9 columns]

# %%
#primary의 'fips','party' 컬럼과 counties의 'fips'와 'RHI425214' 컬럼  outer join
#pd.merge(primary[['fips','party']], counties[['fips','RHI425214']], on="fips") #13211
pd.merge(primary[['fips','party']], counties[['fips','RHI425214']], on="fips",how='outer') #14358
# Out:
#         fips       party  RHI425214
# 0       1001  Republican        1.1
# 1       1001  Republican        1.1
# 2       1001  Republican        1.1
# 3       1001  Republican        1.1
# 4       1001  Republican        1.1
# ...      ...         ...        ...
# 14354  56037         NaN        0.9
# 14355  56039         NaN        1.3
# 14356  56041         NaN        0.5
# 14357  56043         NaN        0.7
# 14358  56045         NaN        0.4
#
# [14359 rows x 3 columns]

# %%
#100개의 row 만 가져와서 merge 함
pd.merge(primary.loc[:100,['state','fips','county','party']], counties.loc[:100,['fips','area_name','RHI425214']], on="fips",how='left')
# Out:
#        state  fips    county       party        area_name  RHI425214
# 0    Alabama  1001   Autauga  Republican   Autauga County        1.1
# 1    Alabama  1001   Autauga  Republican   Autauga County        1.1
# 2    Alabama  1001   Autauga  Republican   Autauga County        1.1
# 3    Alabama  1001   Autauga  Republican   Autauga County        1.1
# 4    Alabama  1001   Autauga  Republican   Autauga County        1.1
# ..       ...   ...       ...         ...              ...        ...
# 96   Alabama  1027      Clay    Democrat      Clay County        0.3
# 97   Alabama  1027      Clay    Democrat      Clay County        0.3
# 98   Alabama  1029  Cleburne  Republican  Cleburne County        0.2
# 99   Alabama  1029  Cleburne  Republican  Cleburne County        0.2
# 100  Alabama  1029  Cleburne  Republican  Cleburne County        0.2
#
# [101 rows x 6 columns]

# %%
primary['state'].unique()
# Out:
# array(['Alabama', 'Arizona', 'Arkansas', 'Colorado', 'Florida', 'Georgia',
#        'Idaho', 'Illinois', 'Iowa', 'Kentucky', 'Louisiana', 'Maine',
#        'Massachusetts', 'Michigan', 'Mississippi', 'Missouri', 'Nebraska',
#        'Nevada', 'North Carolina', 'Ohio', 'Oklahoma', 'South Carolina',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia',
#        'New Hampshire'], dtype=object)

# %%
primary['state'].value_counts()
# Out:
# Texas             1764
# Iowa              1470
# Georgia           1106
# Virginia           693
# Tennessee          658
# Missouri           648
# North Carolina     594
# Illinois           570
# Oklahoma           532
# Ohio               528
# Arkansas           518
# Michigan           486
# Mississippi        480
# Kentucky           480
# Alabama            455
# Florida            378
# South Carolina     368
# Louisiana          312
# Idaho              258
# Nebraska           186
# Utah               145
# Colorado           128
# Nevada             119
# New Hampshire      100
# Vermont             77
# Arizona             75
# Massachusetts       64
# Maine               20
# Name: state, dtype: int64

# %%
primary.loc[primary['state'] == 'Maine',:]
# Out:
#       state state_abbreviation      county   fips     party        candidate  \
# 5750  Maine                 ME  Cumberland  23005  Democrat   Bernie Sanders
# 5751  Maine                 ME  Cumberland  23005  Democrat  Hillary Clinton
# 5752  Maine                 ME    Franklin  23007  Democrat   Bernie Sanders
# 5753  Maine                 ME    Franklin  23007  Democrat  Hillary Clinton
# 5754  Maine                 ME     Hancock  23009  Democrat   Bernie Sanders
# 5755  Maine                 ME     Hancock  23009  Democrat  Hillary Clinton
# 5756  Maine                 ME        Knox  23013  Democrat   Bernie Sanders
# 5757  Maine                 ME        Knox  23013  Democrat  Hillary Clinton
# 5758  Maine                 ME     Lincoln  23015  Democrat   Bernie Sanders
# 5759  Maine                 ME     Lincoln  23015  Democrat  Hillary Clinton
# 5760  Maine                 ME      Oxford  23017  Democrat   Bernie Sanders
# 5761  Maine                 ME      Oxford  23017  Democrat  Hillary Clinton
# 5762  Maine                 ME   Penobscot  23019  Democrat   Bernie Sanders
# 5763  Maine                 ME   Penobscot  23019  Democrat  Hillary Clinton
# 5764  Maine                 ME       Waldo  23027  Democrat  Hillary Clinton
# 5765  Maine                 ME       Waldo  23027  Democrat   Bernie Sanders
# 5766  Maine                 ME  Washington  23029  Democrat   Bernie Sanders
# 5767  Maine                 ME  Washington  23029  Democrat  Hillary Clinton
# 5768  Maine                 ME        York  23031  Democrat   Bernie Sanders
# 5769  Maine                 ME        York  23031  Democrat  Hillary Clinton
#
#       votes  fraction_votes
# 5750     15           0.556
# 5751     12           0.444
# 5752      2           0.667
# 5753      1           0.333
# 5754      3           0.600
# 5755      2           0.400
# 5756      1           1.000
# 5757      0           0.000
# 5758      5           0.556
# 5759      4           0.444
# 5760      4           0.667
# 5761      2           0.333
# 5762      4           0.800
# 5763      1           0.200
# 5764      0           0.000
# 5765      0           0.000
# 5766      2           0.667
# 5767      1           0.333
# 5768     25           0.595
# 5769     17           0.405

# %%
#Maine state 인 row 의 merge
pd.merge(primary.loc[primary['state'] == 'Maine',['state','fips','county','party','candidate']],\
         counties.loc[:,['fips','area_name','RHI425214']], on="fips",how='left')
# Out:
#     state   fips      county     party        candidate          area_name  \
# 0   Maine  23005  Cumberland  Democrat   Bernie Sanders  Cumberland County
# 1   Maine  23005  Cumberland  Democrat  Hillary Clinton  Cumberland County
# 2   Maine  23007    Franklin  Democrat   Bernie Sanders    Franklin County
# 3   Maine  23007    Franklin  Democrat  Hillary Clinton    Franklin County
# 4   Maine  23009     Hancock  Democrat   Bernie Sanders     Hancock County
# 5   Maine  23009     Hancock  Democrat  Hillary Clinton     Hancock County
# 6   Maine  23013        Knox  Democrat   Bernie Sanders        Knox County
# 7   Maine  23013        Knox  Democrat  Hillary Clinton        Knox County
# 8   Maine  23015     Lincoln  Democrat   Bernie Sanders     Lincoln County
# 9   Maine  23015     Lincoln  Democrat  Hillary Clinton     Lincoln County
# 10  Maine  23017      Oxford  Democrat   Bernie Sanders      Oxford County
# 11  Maine  23017      Oxford  Democrat  Hillary Clinton      Oxford County
# 12  Maine  23019   Penobscot  Democrat   Bernie Sanders   Penobscot County
# 13  Maine  23019   Penobscot  Democrat  Hillary Clinton   Penobscot County
# 14  Maine  23027       Waldo  Democrat  Hillary Clinton       Waldo County
# 15  Maine  23027       Waldo  Democrat   Bernie Sanders       Waldo County
# 16  Maine  23029  Washington  Democrat   Bernie Sanders  Washington County
# 17  Maine  23029  Washington  Democrat  Hillary Clinton  Washington County
# 18  Maine  23031        York  Democrat   Bernie Sanders        York County
# 19  Maine  23031        York  Democrat  Hillary Clinton        York County
#
#     RHI425214
# 0         2.2
# 1         2.2
# 2         0.7
# 3         0.7
# 4         1.1
# 5         1.1
# 6         0.6
# 7         0.6
# 8         0.8
# 9         0.8
# 10        0.7
# 11        0.7
# 12        1.1
# 13        1.1
# 14        0.6
# 15        0.6
# 16        0.6
# 17        0.6
# 18        1.3
# 19        1.3

# %%
#fips 컬럼을 index로 변경함
counties2 = counties.set_index("fips")
counties2.head()
# Out:
#            area_name state_abbreviation  PST045214  PST040210  PST120214  \
# fips
# 0      United States                NaN  318857056  308758105        3.3
# 1000         Alabama                NaN    4849377    4780127        1.4
# 1001  Autauga County                 AL      55395      54571        1.5
# 1003  Baldwin County                 AL     200111     182265        9.8
# 1005  Barbour County                 AL      26887      27457       -2.1
#
#       POP010210  AGE135214  AGE295214  AGE775214  SEX255214  ...  SBO415207  \
# fips                                                         ...
# 0     308745538        6.2       23.1       14.5       50.8  ...        8.3
# 1000    4779736        6.1       22.8       15.3       51.5  ...        1.2
# 1001      54571        6.0       25.2       13.8       51.4  ...        0.7
# 1003     182265        5.6       22.2       18.7       51.2  ...        1.3
# 1005      27457        5.7       21.2       16.5       46.6  ...        0.0
#
#       SBO015207   MAN450207   WTN220207   RTN130207  RTN131207  AFN120207  \
# fips
# 0          28.8  5319456312  4174286516  3917663456      12990  613795732
# 1000       28.1   112858843    52252752    57344851      12364    6426342
# 1001       31.7           0           0      598175      12003      88157
# 1003       27.3     1410273           0     2966489      17166     436955
# 1005       27.0           0           0      188337       6334          0
#
#       BPS030214   LND110210  POP060210
# fips
# 0       1046363  3531905.43       87.4
# 1000      13369    50645.33       94.4
# 1001        131      594.44       91.8
# 1003       1384     1589.78      114.6
# 1005          8      884.88       31.0
#
# [5 rows x 53 columns]

# %%
#인덱스 기준 merging
pd.merge(primary, counties2[['area_name','PST045214']], left_on="fips", right_index=True).head()
#pd.merge(primary[['fips','county','party']], counties2[['area_name','PST045214']], left_on="fips", right_index=True)
# Out:
#      state state_abbreviation   county  fips       party     candidate  votes  \
# 0  Alabama                 AL  Autauga  1001  Republican  Donald Trump   5387
# 1  Alabama                 AL  Autauga  1001  Republican      Ted Cruz   2482
# 2  Alabama                 AL  Autauga  1001  Republican   Marco Rubio   1785
# 3  Alabama                 AL  Autauga  1001  Republican    Ben Carson   1764
# 4  Alabama                 AL  Autauga  1001  Republican   John Kasich    421
#
#    fraction_votes       area_name  PST045214
# 0           0.445  Autauga County      55395
# 1           0.205  Autauga County      55395
# 2           0.148  Autauga County      55395
# 3           0.146  Autauga County      55395
# 4           0.035  Autauga County      55395

# %%
primary.head()
# Out:
#      state state_abbreviation   county  fips       party     candidate  votes  \
# 0  Alabama                 AL  Autauga  1001  Republican  Donald Trump   5387
# 1  Alabama                 AL  Autauga  1001  Republican      Ted Cruz   2482
# 2  Alabama                 AL  Autauga  1001  Republican   Marco Rubio   1785
# 3  Alabama                 AL  Autauga  1001  Republican    Ben Carson   1764
# 4  Alabama                 AL  Autauga  1001  Republican   John Kasich    421
#
#    fraction_votes
# 0           0.445
# 1           0.205
# 2           0.148
# 3           0.146
# 4           0.035

# %%
#계층적 인덱싱 만들기
primary2 = primary.set_index(["state","county"])

# %%
primary2.head()
# Out:
#                 state_abbreviation  fips       party     candidate  votes  \
# state   county
# Alabama Autauga                 AL  1001  Republican  Donald Trump   5387
#         Autauga                 AL  1001  Republican      Ted Cruz   2482
#         Autauga                 AL  1001  Republican   Marco Rubio   1785
#         Autauga                 AL  1001  Republican    Ben Carson   1764
#         Autauga                 AL  1001  Republican   John Kasich    421
#
#                  fraction_votes
# state   county
# Alabama Autauga           0.445
#         Autauga           0.205
#         Autauga           0.148
#         Autauga           0.146
#         Autauga           0.035

# %%
#3개의 컬럼을 인덱스로 변경해줌
primary2 = primary.set_index(["state","county","party"])

# %%
primary2.head()
# Out:
#                            state_abbreviation  fips     candidate  votes  \
# state   county  party
# Alabama Autauga Republican                 AL  1001  Donald Trump   5387
#                 Republican                 AL  1001      Ted Cruz   2482
#                 Republican                 AL  1001   Marco Rubio   1785
#                 Republican                 AL  1001    Ben Carson   1764
#                 Republican                 AL  1001   John Kasich    421
#
#                             fraction_votes
# state   county  party
# Alabama Autauga Republican           0.445
#                 Republican           0.205
#                 Republican           0.148
#                 Republican           0.146
#                 Republican           0.035

# %%
#기존 열을 그대로 유지하고 싶다면 drop=False
primary2 = primary.set_index(["state","county","party"],drop=False)

# %%
#각 후보가 당선된 county의 평균 백인 유권자 비율 조사하기 하기전에 연습할 내용

# %%
#fips 마다 후보자들의 득표수가 있다는 것을 확인함
primary.loc[primary["fips"] == 1005,:].sort_values("votes",ascending=False)
# Out:
#       state state_abbreviation   county  fips       party        candidate  \
# 19  Alabama                 AL  Barbour  1005    Democrat  Hillary Clinton
# 14  Alabama                 AL  Barbour  1005  Republican     Donald Trump
# 15  Alabama                 AL  Barbour  1005  Republican         Ted Cruz
# 16  Alabama                 AL  Barbour  1005  Republican      Marco Rubio
# 17  Alabama                 AL  Barbour  1005  Republican       Ben Carson
# 20  Alabama                 AL  Barbour  1005    Democrat   Bernie Sanders
# 18  Alabama                 AL  Barbour  1005  Republican      John Kasich
#
#     votes  fraction_votes
# 19   2567           0.906
# 14   1710           0.501
# 15    609           0.179
# 16    498           0.146
# 17    417           0.122
# 20    222           0.078
# 18    123           0.036

# %%
primary.loc[primary["fips"] == 1005,:].sort_values("votes",ascending=False).iloc[0]
# Out:
# state                         Alabama
# state_abbreviation                 AL
# county                        Barbour
# fips                             1005
# party                        Democrat
# candidate             Hillary Clinton
# votes                            2567
# fraction_votes                  0.906
# Name: 19, dtype: object

# %%
#fips별 최대 득표수
primary.groupby("fips")["votes"].max()
# Out:
# fips
# 1001      5387
# 1003     23618
# 1005      2567
# 1007      1959
# 1009      7390
#          ...
# 51650    13529
# 51700    12495
# 51710    15747
# 51800     7533
# 51810    22352
# Name: votes, Length: 2048, dtype: int64

# %%
#각 후보가 당선된 county의 평균 백인 유권자 비율 조사하기
func = lambda agg_df: agg_df.sort_values("votes", ascending=False).iloc[0]
winners = primary.groupby("fips").agg(func)

# %%
winners.head()
# Out:
#         state state_abbreviation   county       party        candidate  votes  \
# fips
# 1001  Alabama                 AL  Autauga  Republican     Donald Trump   5387
# 1003  Alabama                 AL  Baldwin  Republican     Donald Trump  23618
# 1005  Alabama                 AL  Barbour    Democrat  Hillary Clinton   2567
# 1007  Alabama                 AL     Bibb  Republican     Donald Trump   1959
# 1009  Alabama                 AL   Blount  Republican     Donald Trump   7390
#
#       fraction_votes
# fips
# 1001           0.445
# 1003           0.469
# 1005           0.906
# 1007           0.494
# 1009           0.487

# %%
#primary와 counties 데이터프레임을 merge 한다.  White alone(백인)
winners_county_races = pd.merge(winners, counties[["fips", "RHI825214"]], left_index=True, right_on="fips", how="left")

# %%
winners_county_races.head()
# Out:
#      state state_abbreviation   county       party        candidate  votes  \
# 2  Alabama                 AL  Autauga  Republican     Donald Trump   5387
# 3  Alabama                 AL  Baldwin  Republican     Donald Trump  23618
# 4  Alabama                 AL  Barbour    Democrat  Hillary Clinton   2567
# 5  Alabama                 AL     Bibb  Republican     Donald Trump   1959
# 6  Alabama                 AL   Blount  Republican     Donald Trump   7390
#
#    fraction_votes  fips  RHI825214
# 2           0.445  1001       75.6
# 3           0.469  1003       83.0
# 4           0.906  1005       46.6
# 5           0.494  1007       74.5
# 6           0.487  1009       87.8

# %%
#컬럼명  변경
winners_county_races = winners_county_races.rename(columns={"RHI825214":"white_pcts"})

# %%
winners_county_races.head()
# Out:
#      state state_abbreviation   county       party        candidate  votes  \
# 2  Alabama                 AL  Autauga  Republican     Donald Trump   5387
# 3  Alabama                 AL  Baldwin  Republican     Donald Trump  23618
# 4  Alabama                 AL  Barbour    Democrat  Hillary Clinton   2567
# 5  Alabama                 AL     Bibb  Republican     Donald Trump   1959
# 6  Alabama                 AL   Blount  Republican     Donald Trump   7390
#
#    fraction_votes  fips  white_pcts
# 2           0.445  1001        75.6
# 3           0.469  1003        83.0
# 4           0.906  1005        46.6
# 5           0.494  1007        74.5
# 6           0.487  1009        87.8

# %%
winners_county_white_pcts = winners_county_races.groupby(["party", "candidate"])["white_pcts"].mean()

# %%
winners_county_white_pcts
# Out:
# party       candidate
# Democrat    Bernie Sanders     81.944030
#             Hillary Clinton    56.856920
# Republican  Ben Carson         81.100000
#             Donald Trump       83.235638
#             John Kasich        89.226415
#             Marco Rubio        78.883333
#             Ted Cruz           74.164665
# Name: white_pcts, dtype: float64

# %%
#plt.figure()
plt.figure(figsize=(24,10))
ax = winners_county_white_pcts.plot(kind="barh", fontsize=10)
ax.set_xlim([50, 100])
plt.tight_layout()

# %%
#이와 같은 groupby 구문 대신에 위와 같은 pivot_table() 함수를 사용할 수 있다. 
#state별 candidate의 득표수의 합
primary.groupby(["state","candidate"])["votes"].sum()
# Out:
# state      candidate
# Alabama    Ben Carson           84139
#            Bernie Sanders       74987
#            Donald Trump        356892
#            Hillary Clinton     306823
#            John Kasich          37127
#            Marco Rubio         154379
#            Ted Cruz            173277
# Arizona    Bernie Sanders      163400
#            Donald Trump        249916
#            Hillary Clinton     235697
#            John Kasich          53040
#            Ted Cruz            132147
# Arkansas   Ben Carson           23105
#            Bernie Sanders       64514
#            Donald Trump        132546
#            Hillary Clinton     142668
#            John Kasich          15079
#            Marco Rubio         100999
#            Ted Cruz            123379
# Colorado   Bernie Sanders       71928
#            Hillary Clinton      49256
# Florida    Bernie Sanders      547051
#            Donald Trump       1015451
#            Hillary Clinton    1064566
#            John Kasich         150167
#            Marco Rubio         607491
#            Ted Cruz            383189
# Georgia    Ben Carson           78731
#            Bernie Sanders      181760
#            Donald Trump        490566
#                                ...
# Tennessee  Hillary Clinton     244663
#            John Kasich          45155
#            Marco Rubio         180645
#            Ted Cruz            210559
# Texas      Ben Carson          116474
#            Bernie Sanders      471191
#            Donald Trump        744441
#            Hillary Clinton     925323
#            John Kasich         118707
#            Marco Rubio         495825
#            Ted Cruz           1219691
# Utah       Bernie Sanders       61333
#            Donald Trump         24864
#            Hillary Clinton      15666
#            John Kasich          29773
#            Ted Cruz            122567
# Vermont    Ben Carson             275
#            Bernie Sanders       10272
#            Donald Trump          2116
#            Hillary Clinton       1694
#            John Kasich           1916
#            Marco Rubio           1267
#            Ted Cruz               681
# Virginia   Ben Carson           51186
#            Bernie Sanders      218517
#            Donald Trump        311174
#            Hillary Clinton     399943
#            John Kasich          82701
#            Marco Rubio         280872
#            Ted Cruz            151738
# Name: votes, Length: 178, dtype: int64

# %%
total_votes = primary.pivot_table(values="votes", index="state", 
                    columns="candidate", aggfunc="sum",fill_value=0)

# %%
total_votes
# Out:
# candidate        No Preference   Uncommitted  Ben Carson  Bernie Sanders  \
# state
# Alabama                      0             0       84139           74987
# Arizona                      0             0           0          163400
# Arkansas                     0             0       23105           64514
# Colorado                     0             0           0           71928
# Florida                      0             0           0          547051
# Georgia                      0             0       78731          181760
# Idaho                        0             0           0           18550
# Illinois                     0             0           0          354344
# Iowa                         0            43       17173           69311
# Kentucky                     0             0           0               0
# Louisiana                    0             0           0           62723
# Maine                        0             0           0              61
# Massachusetts              313             0         877           26102
# Michigan                     0             0           0          587838
# Mississippi                  0             0           0           34218
# Missouri                     0             0           0          184883
# Nebraska                     0             0           0           19120
# Nevada                       0             0        3619            5641
# New Hampshire                0             0        6509          151584
# North Carolina               0             0           0          459606
# Ohio                         0             0           0          513549
# Oklahoma                     0             0       28378          171771
# South Carolina               0             0       53326           95977
# Tennessee                    0             0       64671          120047
# Texas                        0             0      116474          471191
# Utah                         0             0           0           61333
# Vermont                      0             0         275           10272
# Virginia                     0             0       51186          218517
#
# candidate       Carly Fiorina  Chris Christie  Donald Trump  Hillary Clinton  \
# state
# Alabama                     0               0        356892           306823
# Arizona                     0               0        249916           235697
# Arkansas                    0               0        132546           142668
# Colorado                    0               0             0            49256
# Florida                     0               0       1015451          1064566
# Georgia                     0               0        490566           460660
# Idaho                       0               0         60810             5017
# Illinois                    0               0        350991           304632
# Iowa                     3475            3278         45163            69581
# Kentucky                    0               0         82493                0
# Louisiana                   0               0        100781           194126
# Maine                       0               0             0               40
# Massachusetts               0               0         16110            25198
# Michigan                    0               0        469228           571748
# Mississippi                 0               0        180485           175221
# Missouri                    0               0        291817           165624
# Nebraska                    0               0             0            14340
# Nevada                      0               0         34531             6296
# New Hampshire           11706           21069        100406            95252
# North Carolina              0               0        455783           615603
# Ohio                        0               0        727585           679266
# Oklahoma                    0               0        129192           137840
# South Carolina              0               0        239851           271514
# Tennessee                   0               0        331462           244663
# Texas                       0               0        744441           925323
# Utah                        0               0         24864            15666
# Vermont                     0               0          2116             1694
# Virginia                    0               0        311174           399943
#
# candidate       Jeb Bush  John Kasich  Marco Rubio  Martin O'Malley  \
# state
# Alabama                0        37127       154379                0
# Arizona                0        53040            0                0
# Arkansas               0        15079       100999                0
# Colorado               0            0            0                0
# Florida                0       150167       607491                0
# Georgia                0        66740       297748                0
# Idaho                  0        16251        34976                0
# Illinois               0       153761        72233                0
# Iowa                5221         3466        42883              747
# Kentucky               0        33134        37579                0
# Louisiana              0        15996        28071                0
# Maine                  0            0            0                0
# Massachusetts          0         5662         5645                0
# Michigan               0       314871       121296                0
# Mississippi            0        34249        19215                0
# Missouri               0        57725        37421                0
# Nebraska               0            0            0                0
# Nevada                 0         2709        17940                0
# New Hampshire      31310        44909        30032                0
# North Carolina         0       143837        87466                0
# Ohio                   0       956762        59418                0
# Oklahoma               0        16463       119053                0
# South Carolina     57863        56206       165881                0
# Tennessee              0        45155       180645                0
# Texas                  0       118707       495825                0
# Utah                   0        29773            0                0
# Vermont                0         1916         1267                0
# Virginia               0        82701       280872                0
#
# candidate       Mike Huckabee  Rand Paul  Rick Santorum  Ted Cruz
# state
# Alabama                     0          0              0    173277
# Arizona                     0          0              0    132147
# Arkansas                    0          0              0    123379
# Colorado                    0          0              0         0
# Florida                     0          0              0    383189
# Georgia                     0          0              0    298304
# Idaho                       0          0              0     99447
# Illinois                    0          0              0    304903
# Iowa                     3300       8460           1773     51316
# Kentucky                    0          0              0     72503
# Louisiana                   0          0              0     95169
# Maine                       0          0              0         0
# Massachusetts               0          0              0      3223
# Michigan                    0          0              0    322514
# Mississippi                 0          0              0    134347
# Missouri                    0          0              0    293832
# Nebraska                    0          0              0         0
# Nevada                      0          0              0     16079
# New Hampshire               0          0              0     33189
# North Carolina              0          0              0    417728
# Ohio                        0          0              0    267592
# Oklahoma                    0          0              0    156643
# South Carolina              0          0              0    164790
# Tennessee                   0          0              0    210559
# Texas                       0          0              0   1219691
# Utah                        0          0              0    122567
# Vermont                     0          0              0       681
# Virginia                    0          0              0    151738

# %%
#state_abbreviation별, party 별 투표비율의 평균
primary.groupby(['state_abbreviation','party'])["fraction_votes"].mean()
# Out:
# state_abbreviation  party
# AL                  Democrat      0.476823
#                     Republican    0.195277
# AR                  Democrat      0.464784
#                     Republican    0.191924
# AZ                  Democrat      0.478433
#                     Republican    0.283867
# CO                  Democrat      0.481016
# FL                  Democrat      0.469349
#                     Republican    0.242413
# GA                  Democrat      0.493525
#                     Republican    0.196939
# IA                  Democrat      0.250003
#                     Republican    0.090857
# ID                  Democrat      0.494733
#                     Republican    0.240773
# IL                  Democrat      0.489632
#                     Republican    0.242013
# KY                  Republican    0.245298
# LA                  Democrat      0.451481
#                     Republican    0.240803
# MA                  Democrat      0.331875
#                     Republican    0.193800
# ME                  Democrat      0.450000
# MI                  Democrat      0.487741
#                     Republican    0.237265
# MO                  Democrat      0.489403
#                     Republican    0.243236
# MS                  Democrat      0.493563
#                     Republican    0.243344
# NC                  Democrat      0.462404
#                     Republican    0.242886
# NE                  Democrat      0.489258
# NH                  Democrat      0.500000
#                     Republican    0.125000
# NV                  Democrat      0.498559
#                     Republican    0.199047
# OH                  Democrat      0.492199
#                     Republican    0.245074
# OK                  Democrat      0.442500
#                     Republican    0.196789
# SC                  Democrat      0.496587
#                     Republican    0.166649
# TN                  Democrat      0.486037
#                     Republican    0.195819
# TX                  Democrat      0.479496
#                     Republican    0.191347
# UT                  Democrat      0.438103
#                     Republican    0.333379
# VA                  Democrat      0.496778
#                     Republican    0.197768
# VT                  Democrat      0.498591
#                     Republican    0.193273
# Name: fraction_votes, dtype: float64

# %%
#pivot_table 사용
mean_frac_votes=primary.pivot_table(values="fraction_votes", index="state_abbreviation", 
                    columns="party", aggfunc="mean")

# %%
mean_frac_votes
# Out:
# party               Democrat  Republican
# state_abbreviation
# AL                  0.476823    0.195277
# AR                  0.464784    0.191924
# AZ                  0.478433    0.283867
# CO                  0.481016         NaN
# FL                  0.469349    0.242413
# GA                  0.493525    0.196939
# IA                  0.250003    0.090857
# ID                  0.494733    0.240773
# IL                  0.489632    0.242013
# KY                       NaN    0.245298
# LA                  0.451481    0.240803
# MA                  0.331875    0.193800
# ME                  0.450000         NaN
# MI                  0.487741    0.237265
# MO                  0.489403    0.243236
# MS                  0.493563    0.243344
# NC                  0.462404    0.242886
# NE                  0.489258         NaN
# NH                  0.500000    0.125000
# NV                  0.498559    0.199047
# OH                  0.492199    0.245074
# OK                  0.442500    0.196789
# SC                  0.496587    0.166649
# TN                  0.486037    0.195819
# TX                  0.479496    0.191347
# UT                  0.438103    0.333379
# VA                  0.496778    0.197768
# VT                  0.498591    0.193273
